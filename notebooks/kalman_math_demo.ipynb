# %% [markdown]
# # Adaptive Kalman Filter (AKF) Math Playground
# This notebook demonstrates the underlying math used in the LD2420 C++ firmware.

# %%
import numpy as np
import matplotlib.pyplot as plt

# State matrix [Position, Velocity, Acceleration]
x = np.array([0, 0, 0]).reshape(3, 1)
P = np.eye(3) * 1000  # Initial uncertainty

print('Initial State:', x.flatten())
